# %%
def getATCG (seq): 
    seq=seq.upper()
    num_A = seq.count("A") 
    num_T = seq.count("T") 
    num_C = seq.count ("C") 
    num_G = seq.count ("G") 
    pa=num_A/len(seq)
    pg=num_G/len(seq)
    pc=num_C/len(seq)
    pt=num_T/len(seq)
    print ("Total number of nitrogene bases :", len(seq))
    print ("A:",num_A ,", Percentage of A:",pa*100,"%")
    print ("G:",num_G ,", Percentage of G:",pg*100,"%")
    print ("C:",num_C ,", Percentage of C:",pc*100,"%")
    print ("T:",num_T ,", Percentage of T:",pt*100,"%")
    
#seqq=input("Inter the DNA sequence:")
#getATCG(seqq)
########################################
def comp_strand(seq):
    seq=seq.upper()
    comp=""
    for base in seq:
        if base == "A" :
            comp+= "T"
 
        elif base == "T" :
            comp+= "A"
  
        elif base == "G" :
            comp+= "C"
 
        elif base == "C" :
            comp+= "G"
   
        else :
            print("Wrong input")
            comp=None
            break
    print ("DNA strand :", seq)
    print ("Complimentary strand :", comp)
 #####################################
def num_occ(seq,gene):
    seq=seq.upper()
    gene =gene.upper()
    c=0
    c=seq.count(gene)
    if c==0:
        print ("This Gene doesnot exist in the DNA ")
    else :
        print ("Number of Occurance of this gene :",c)
#seqq=input("Enter the DNA sequence :")
#g=input("Enter the gene :")
#num_occ(seqq,g)
############################################
def find_amino(seq):  
    seq=seq.upper()
    if(seq.count('A')+seq.count('C')+seq.count('G')+seq.count('T')!=len(seq) or len(seq)%3!=0):
        print('wrong input')
    else:    
        table = {  
      'ATA':'I', 'ATC':'I', 'ATT':'I', 'ATG':'M',  
      'ACA':'T', 'ACC':'T', 'ACG':'T', 'ACT':'T',  
      'AAC':'N', 'AAT':'N', 'AAA':'K', 'AAG':'K',  
      'AGC':'S', 'AGT':'S', 'AGA':'R', 'AGG':'R',   
      'CTA':'L', 'CTC':'L', 'CTG':'L', 'CTT':'L',  
      'CCA':'P', 'CCC':'P', 'CCG':'P', 'CCT':'P',  
      'CAC':'H', 'CAT':'H', 'CAA':'Q', 'CAG':'Q',  
      'CGA':'R', 'CGC':'R', 'CGG':'R', 'CGT':'R',  
      'GTA':'V', 'GTC':'V', 'GTG':'V', 'GTT':'V',  
      'GCA':'A', 'GCC':'A', 'GCG':'A', 'GCT':'A',  
      'GAC':'D', 'GAT':'D', 'GAA':'E', 'GAG':'E',  
      'GGA':'G', 'GGC':'G', 'GGG':'G', 'GGT':'G',  
      'TCA':'S', 'TCC':'S', 'TCG':'S', 'TCT':'S',  
      'TTC':'F', 'TTT':'F', 'TTA':'L', 'TTG':'L',  
      'TAC':'Y', 'TAT':'Y', 'TAA':'_', 'TAG':'_',  
      'TGC':'C', 'TGT':'C', 'TGA':'_', 'TGG':'W',  
      }  
        a=""  
   
        for i in range(0, len(seq), 3): 
            c= seq[i:i + 3]  
            a+= table[c]
        print(" The protein :",a)   
             
    
    
#seqq=input("Enter the DNA sequence:")
#find_amino(seqq)

##############################################3
def sim(s1,s2):
    s1=s1.upper()
    s2=s2.upper()
    c = [[None]*(len(s2) + 1) for x in range(len(s1) + 1)] 
    for i in range(len(s1)+1):
        for j in range(len(s2)+1):
            if i == 0 or j == 0 :
                c[i][j] = 0
            elif s1[i-1] == s2[j-1]:
                c[i][j] = c[i-1][j-1]+1
            else:
                c[i][j] = max(c[i-1][j],c[i][j-1])    
    n= c[len(s1)][len(s2)]
    # Create a character array to store the lcs string
    lcs = [""]*(n+1)

    # Start from the right-most-bottom-most corner and one by one store characters in lcs[]
    i =len(s1)
    j = len(s2)
    while i> 0 and j> 0:

        # If current character in s1[] and s2 are same, then the current one is part of the LCS
        if s1[i-1] == s2[j-1]:
            lcs[n-1] = s1[i-1]
            i-=1
            j-=1
            n-=1

        # If not same, then find the larger of two and go in the direction of larger value
        elif c[i-1][j] >c[i][j-1]:
            i-=1
        else:
            j-=1
    return lcs
#s1= input('Enter the first DNA sequance: ')
#s2 = input('Enter the second DNA sequence: ')
#print('The similarity : ', end='')
#print(sim(s1,s2))
######################333
def opt():
    print ("*  HERE is The processes .                                                                                          *")
    print ("*                                                                                                                   *")
    print ("* <1> Get the number of each nitrogene base and it's percentage.                                                    *")
    print ("*                                                                                                                   *")                            
    print ("* <2> Get the complimentary of the DNA strand.                                                                      *")
    print ("*                                                                                                                   *")
    print ("* <3> Get the number of gene occurance.                                                                             *")
    print ("*                                                                                                                   *")                            
    print ("* <4> Protein translation.                                                                                          *")
    print ("*                                                                                                                   *")                            
    print ("* <5> Find the similarity between 2 DNA sequences.                                                                  *")
    s=int(input("* Enter your process number:  "))
    print ("*")
    if s==1:
        seqq=input("* Enter the DNA sequence:")
        print("*")
        getATCG(seqq)
    elif s==2:
        seqq=input("* Enter the DNA sequqnce:")
        print("*")
        comp_strand(seqq)
    elif s==3:
        seqq=input("* Enter the DNA sequence :")
        g=input("* Enter the gene :")
        print("*")
        num_occ(seqq,g)
    elif s==4:
        seqq=input("* Enter the DNA sequence:")
        print("*")
        find_amino(seqq)
    elif s==5:
        s1= input('* Enter the first DNA sequance: ')
        s2 = input('* Enter the second DNA sequence: ')
        print("*")
        print('* The similarity : ', end='')
        print(sim(s1,s2))
    else :
        print ("* There is no option selected , please try again.")
        print("*")
        opt()
    print ("*                                                                                                                   *")                            
    print ("*DO you want to do another process ?                                                                                *")
    print ("*                                                                                                                   *")
    print ("* <1> YES.                                                                                                          *")
    print ("*                                                                                                                   *")
    print ("* <2> NO                                                                                                            *")
    o=int(input("Enter your choice:"))
    print ("*                                                                                                                   *")
    if o==1:
        opt()
    elif o==2:
        print ("*********************************************************************************************************************")
        print ("*                                                                                                                   *")                            
        print ("*                                                                                                                   *")                            
        print ("*                                                                                                                   *")                            
        print ("*                             ----------------------------------------                                              *")                       
        print ("*                            | ^_^ |  Thanks for using our App  | ^_^ |                                             *")
        print ("*                             ----------------------------------------                                              *")                       
        print ("*                                                                                                                   *")                            
        print ("*                                                                                                                   *")                            
        print ("*                                                                                                                   *")                            
        print ("*********************************************************************************************************************")

        
###########################################################################

print ("*********************************************************************************************************************")
print ("*********************************************************************************************************************")
print ("*                       * *  * * * * * * * * * * * * * * * * * * * * * * * * * * * *   * *                          *")
print ("*                     * ^_^ * Welcome to our application for sequencing data analysis* ^_^ *                        *")
print ("*                       * *  * * * * * * * * * * * * * * * * * * * * * * * * * * * *   * *                          *")
print ("*********************************************************************************************************************")
print ("*                                                                                                                   *")
print ("*  HERE is The processes .                                                                                          *")
print ("*                                                                                                                   *")
print ("* <1> Get the number of each nitrogene base and it's percentage.                                                    *")
print ("*                                                                                                                   *")                            
print ("* <2> Get the complimentary of the DNA strand.                                                                      *")
print ("*                                                                                                                   *")
print ("* <3> Get the number of gene occurance.                                                                             *")
print ("*                                                                                                                   *")                            
print ("* <4> Protein translation.                                                                                          *")
print ("*                                                                                                                   *")                            
print ("* <5> Find the similarity between 2 DNA sequences.                                                              *")
print ("*                                                                                                                   *")                            

s=int(input("* Enter your process number:  "))
print ("*")
if s==1:
    seqq=input("* Enter the DNA sequence:")
    print("*")
    getATCG(seqq)
elif s==2:
    seqq=input("* Enter the DNA sequqnce:")
    print("*")
    comp_strand(seqq)
elif s==3:
    seqq=input("* Enter the DNA sequence :")
    g=input("* Enter the gene :")
    print("*")
    num_occ(seqq,g)
elif s==4:
    seqq=input("* Enter the DNA sequence:")
    print("*")
    find_amino(seqq)
elif s==5:
    s1= input('* Enter the first DNA sequance: ')
    s2 = input('* Enter the second DNA sequence: ')
    print("*")
    print('* The similarity : ', end='')
    print(sim(s1,s2))
else :
    print ("* There is no option selected , please try again.")
    print ("*                                                                                                                   *")
    opt()
print ("*                                                                                                                   *")                            

print ("*DO you want to do another process ?                                                                                *")
print ("*                                                                                                                   *")
print ("* <1> YES.                                                                                                          *")
print ("*                                                                                                                   *")
print ("* <2> NO                                                                                                            *")
o=int(input("Enter your choice:"))
print ("*                                                                                                                   *")
if o==1:
    opt()
elif o==2:
    print ("*********************************************************************************************************************")
    print ("*                                                                                                                   *")                            
    print ("*                                                                                                                   *")                            
    print ("*                                                                                                                   *")                            
    print ("*                             ----------------------------------------                                              *")                       
    print ("*                            | ^_^ |  Thanks for using our App  | ^_^ |                                             *")
    print ("*                             ----------------------------------------                                              *")                       
    print ("*                                                                                                                   *")                            
    print ("*                                                                                                                   *")                            
    print ("*                                                                                                                   *")                            
    print ("*********************************************************************************************************************")
